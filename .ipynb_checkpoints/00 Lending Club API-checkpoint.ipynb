# %% [markdown]
# # Consumer Lending Analysis: Lending Club
#
# ## 1. Lending Club Python API
#
# An unofficial stand-alone python module for interacting with *Lending Club* account. Credit to [Jeremy Gillick](https://github.com/jgillick/LendingClub).
# Easier to use. The core is the official API Lending Club provided.

# %%
from lendingclub import LendingClub
from lendingclub.filters import Filter
from lendingclub.filters import FilterByLoanID
from lendingclub.filters import SavedFilter
from pprint import pprint

# %%
# Authenticate with your lending club credentials

lc = LendingClub()
lc.authenticate()

# %%
# See the cash you have available for investing
# Yes I don't have money to invest :)

print(lc.get_cash_balance())
print(lc.get_investable_balance())
# Out:
# 0.0
# 0

# %%
# The default search filter that let you refine your search based on a dictionary of search facets. 

filters = Filter()
pprint(filters)
# Out:
# {'exclude_existing': True,
#  'funding_progress': 0,
#  'grades': {'A': False,
#             'All': True,
#             'B': False,
#             'C': False,
#             'D': False,
#             'E': False,
#             'F': False,
#             'G': False},
#  'term': {'Year3': True, 'Year5': True}}

# %%
# Set the search filters

filters = Filter()
filters['grades']['All'] = True

# filters['grades']['B'] = True
# filters['grades']['C'] = True
# filters['grades']['D'] = True
# filters['term']['Year5'] = False
# filters['funding_progress'] = 90

# OR

# filters = Filter({'grades': ... , 'term': ... , 'funding_progress': ...})

pprint(filters)
# Out:
# {'exclude_existing': True,
#  'funding_progress': 0,
#  'grades': {'A': False,
#             'All': True,
#             'B': False,
#             'C': False,
#             'D': False,
#             'E': False,
#             'F': False,
#             'G': False},
#  'term': {'Year3': True, 'Year5': True}}

# %%
results = lc.search(filters, limit = 10000)
results['totalRecords']
# Out:
# 172

# %%
pprint(results['loans'])
# Out:
# [{u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'680-684',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 10075,
#   u'loanAmt': 10075,
#   u'loanAmtRemaining': 350,
#   u'loanGUID': u'119428432',
#   u'loanGrade': u'E2',
#   u'loanLength': 36,
#   u'loanRate': u'23.88',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2320367070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 350,
#   'loan_id': 119428432,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -4.7370004e-06,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -27478930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'695-699',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 4800,
#   u'loanAmt': 4800,
#   u'loanAmtRemaining': 1450,
#   u'loanGUID': u'120616711',
#   u'loanGrade': u'B4',
#   u'loanLength': 36,
#   u'loanRate': u'10.91',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 1450,
#   'loan_id': 120616711,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'car',
#   u'searchrank': -0.002571358,
#   u'title': u'Car financing',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'680-684',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 19850,
#   u'loanAmt': 19850,
#   u'loanAmtRemaining': 16450,
#   u'loanGUID': u'120140225',
#   u'loanGrade': u'B1',
#   u'loanLength': 36,
#   u'loanRate': u'9.44',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2040866070,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 16450,
#   'loan_id': 120140225,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'home_improvement',
#   u'searchrank': -0.0045106886,
#   u'title': u'Home improvement',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'680-684',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 35000,
#   u'loanAmt': 35000,
#   u'loanAmtRemaining': 29300,
#   u'loanGUID': u'120104269',
#   u'loanGrade': u'G3',
#   u'loanLength': 36,
#   u'loanRate': u'30.89',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 1952870070,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 29300,
#   'loan_id': 120104269,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'home_improvement',
#   u'searchrank': -0.010803888,
#   u'title': u'Home improvement',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'710-714',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 5000,
#   u'loanAmt': 5000,
#   u'loanAmtRemaining': 250,
#   u'loanGUID': u'121295277',
#   u'loanGrade': u'E3',
#   u'loanLength': 36,
#   u'loanRate': u'24.85',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 250,
#   'loan_id': 121295277,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'moving',
#   u'searchrank': -0.012544784,
#   u'title': u'Moving and relocation',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'695-699',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 10000,
#   u'loanAmt': 10000,
#   u'loanAmtRemaining': 3250,
#   u'loanGUID': u'120952203',
#   u'loanGrade': u'C5',
#   u'loanLength': 36,
#   u'loanRate': u'16.02',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 3250,
#   'loan_id': 120952203,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -0.029861033,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'715-719',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 8000,
#   u'loanAmt': 8000,
#   u'loanAmtRemaining': 1875,
#   u'loanGUID': u'120264195',
#   u'loanGrade': u'B4',
#   u'loanLength': 36,
#   u'loanRate': u'10.91',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 1875,
#   'loan_id': 120264195,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -0.035422318,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'720-724',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 8950,
#   u'loanAmt': 8950,
#   u'loanAmtRemaining': 6125,
#   u'loanGUID': u'120925783',
#   u'loanGrade': u'D1',
#   u'loanLength': 36,
#   u'loanRate': u'17.09',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 6125,
#   'loan_id': 120925783,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'medical',
#   u'searchrank': -0.06499784,
#   u'title': u'Medical expenses',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'800-804',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 10000,
#   u'loanAmt': 10000,
#   u'loanAmtRemaining': 6150,
#   u'loanGUID': u'120929639',
#   u'loanGrade': u'B1',
#   u'loanLength': 36,
#   u'loanRate': u'9.44',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 6150,
#   'loan_id': 120929639,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'other',
#   u'searchrank': -0.082775414,
#   u'title': u'Other',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'785-789',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 10000,
#   u'loanAmt': 10000,
#   u'loanAmtRemaining': 2700,
#   u'loanGUID': u'121272439',
#   u'loanGrade': u'D1',
#   u'loanLength': 36,
#   u'loanRate': u'17.09',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 2700,
#   'loan_id': 121272439,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'small_business',
#   u'searchrank': -0.10534504,
#   u'title': u'Business',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'680-684',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 6000,
#   u'loanAmt': 6000,
#   u'loanAmtRemaining': 2550,
#   u'loanGUID': u'119280209',
#   u'loanGrade': u'B1',
#   u'loanLength': 36,
#   u'loanRate': u'9.44',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 2550,
#   'loan_id': 119280209,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -0.14330289,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'800-804',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 15000,
#   u'loanAmt': 15000,
#   u'loanAmtRemaining': 3875,
#   u'loanGUID': u'121266729',
#   u'loanGrade': u'B5',
#   u'loanLength': 36,
#   u'loanRate': u'11.99',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 3875,
#   'loan_id': 121266729,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'other',
#   u'searchrank': -0.28931448,
#   u'title': u'Other',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'700-704',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 15000,
#   u'loanAmt': 15000,
#   u'loanAmtRemaining': 8350,
#   u'loanGUID': u'121228179',
#   u'loanGrade': u'B5',
#   u'loanLength': 36,
#   u'loanRate': u'11.99',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 8350,
#   'loan_id': 121228179,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -0.29316792,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'675-679',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 8400,
#   u'loanAmt': 8400,
#   u'loanAmtRemaining': 5675,
#   u'loanGUID': u'121271711',
#   u'loanGrade': u'B1',
#   u'loanLength': 36,
#   u'loanRate': u'9.44',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 5675,
#   'loan_id': 121271711,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'medical',
#   u'searchrank': -0.5179833,
#   u'title': u'Medical expenses',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'660-664',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 12000,
#   u'loanAmt': 12000,
#   u'loanAmtRemaining': 10425,
#   u'loanGUID': u'120954185',
#   u'loanGrade': u'D5',
#   u'loanLength': 36,
#   u'loanRate': u'21.45',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 10425,
#   'loan_id': 120954185,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'small_business',
#   u'searchrank': -0.5423421,
#   u'title': u'Business',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'715-719',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 30000,
#   u'loanAmt': 30000,
#   u'loanAmtRemaining': 27125,
#   u'loanGUID': u'120648425',
#   u'loanGrade': u'B2',
#   u'loanLength': 36,
#   u'loanRate': u'9.93',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 27125,
#   'loan_id': 120648425,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -0.649931,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'665-669',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 15175,
#   u'loanAmt': 15175,
#   u'loanAmtRemaining': 400,
#   u'loanGUID': u'121371470',
#   u'loanGrade': u'E3',
#   u'loanLength': 36,
#   u'loanRate': u'24.85',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2406121070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 400,
#   'loan_id': 121371470,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'other',
#   u'searchrank': -0.8223341,
#   u'title': u'Other',
#   u'wholeLoanTimeRemaining': -185878930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'670-674',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 35000,
#   u'loanAmt': 35000,
#   u'loanAmtRemaining': 27425,
#   u'loanGUID': u'121244905',
#   u'loanGrade': u'D1',
#   u'loanLength': 36,
#   u'loanRate': u'17.09',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2564521070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 27425,
#   'loan_id': 121244905,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -0.9994283,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -27478930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'695-699',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 11200,
#   u'loanAmt': 11200,
#   u'loanAmtRemaining': 9450,
#   u'loanGUID': u'121290708',
#   u'loanGrade': u'D1',
#   u'loanLength': 36,
#   u'loanRate': u'17.09',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 9450,
#   'loan_id': 121290708,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -0.99997175,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'660-664',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 30000,
#   u'loanAmt': 30000,
#   u'loanAmtRemaining': 1125,
#   u'loanGUID': u'121365848',
#   u'loanGrade': u'D3',
#   u'loanLength': 36,
#   u'loanRate': u'19.03',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 1125,
#   'loan_id': 121365848,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -0.99999124,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'700-704',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 12000,
#   u'loanAmt': 12000,
#   u'loanAmtRemaining': 6425,
#   u'loanGUID': u'119341177',
#   u'loanGrade': u'B5',
#   u'loanLength': 36,
#   u'loanRate': u'11.99',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 6425,
#   'loan_id': 119341177,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -0.99999976,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'670-674',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 8000,
#   u'loanAmt': 8000,
#   u'loanAmtRemaining': 100,
#   u'loanGUID': u'121378125',
#   u'loanGrade': u'B3',
#   u'loanLength': 36,
#   u'loanRate': u'10.42',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 75,
#   'loan_id': 121378125,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'credit_card',
#   u'searchrank': -1,
#   u'title': u'Credit card refinancing',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'665-669',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 3600,
#   u'loanAmt': 3600,
#   u'loanAmtRemaining': 125,
#   u'loanGUID': u'121715080',
#   u'loanGrade': u'D1',
#   u'loanLength': 36,
#   u'loanRate': u'17.09',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 125,
#   'loan_id': 121715080,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -1,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'690-694',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 10000,
#   u'loanAmt': 10000,
#   u'loanAmtRemaining': 500,
#   u'loanGUID': u'121416203',
#   u'loanGrade': u'B5',
#   u'loanLength': 36,
#   u'loanRate': u'11.99',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 500,
#   'loan_id': 121416203,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'other',
#   u'searchrank': -1,
#   u'title': u'Other',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'715-719',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 10000,
#   u'loanAmt': 10000,
#   u'loanAmtRemaining': 750,
#   u'loanGUID': u'121703254',
#   u'loanGrade': u'B5',
#   u'loanLength': 36,
#   u'loanRate': u'11.99',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 750,
#   'loan_id': 121703254,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'car',
#   u'searchrank': -1,
#   u'title': u'Car financing',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'680-684',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 10000,
#   u'loanAmt': 10000,
#   u'loanAmtRemaining': 875,
#   u'loanGUID': u'121405909',
#   u'loanGrade': u'E3',
#   u'loanLength': 36,
#   u'loanRate': u'24.85',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2492521070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 875,
#   'loan_id': 121405909,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -1,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -99478930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'680-684',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 10000,
#   u'loanAmt': 10000,
#   u'loanAmtRemaining': 875,
#   u'loanGUID': u'121400461',
#   u'loanGrade': u'D3',
#   u'loanLength': 36,
#   u'loanRate': u'19.03',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2478121070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 875,
#   'loan_id': 121400461,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'credit_card',
#   u'searchrank': -1,
#   u'title': u'Credit card refinancing',
#   u'wholeLoanTimeRemaining': -113878930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'705-709',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 3500,
#   u'loanAmt': 3500,
#   u'loanAmtRemaining': 1075,
#   u'loanGUID': u'121724487',
#   u'loanGrade': u'D2',
#   u'loanLength': 36,
#   u'loanRate': u'18.06',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 1050,
#   'loan_id': 121724487,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'other',
#   u'searchrank': -1,
#   u'title': u'Other',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'725-729',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 15000,
#   u'loanAmt': 15000,
#   u'loanAmtRemaining': 1250,
#   u'loanGUID': u'121234944',
#   u'loanGrade': u'C3',
#   u'loanLength': 36,
#   u'loanRate': u'14.08',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 1250,
#   'loan_id': 121234944,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'home_improvement',
#   u'searchrank': -1,
#   u'title': u'Home improvement',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'725-729',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 7000,
#   u'loanAmt': 7000,
#   u'loanAmtRemaining': 1325,
#   u'loanGUID': u'121705810',
#   u'loanGrade': u'C4',
#   u'loanLength': 36,
#   u'loanRate': u'15.05',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 1300,
#   'loan_id': 121705810,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -1,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'685-689',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 35000,
#   u'loanAmt': 35000,
#   u'loanAmtRemaining': 1575,
#   u'loanGUID': u'121718242',
#   u'loanGrade': u'E1',
#   u'loanLength': 36,
#   u'loanRate': u'22.91',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 1575,
#   'loan_id': 121718242,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -1,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'660-664',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 5000,
#   u'loanAmt': 5000,
#   u'loanAmtRemaining': 1675,
#   u'loanGUID': u'120580030',
#   u'loanGrade': u'B1',
#   u'loanLength': 36,
#   u'loanRate': u'9.44',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 1675,
#   'loan_id': 120580030,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'home_improvement',
#   u'searchrank': -1,
#   u'title': u'Home improvement',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'670-674',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 6125,
#   u'loanAmt': 6125,
#   u'loanAmtRemaining': 1850,
#   u'loanGUID': u'121713750',
#   u'loanGrade': u'E1',
#   u'loanLength': 36,
#   u'loanRate': u'22.91',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 1850,
#   'loan_id': 121713750,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -1,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'765-769',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 6000,
#   u'loanAmt': 6000,
#   u'loanAmtRemaining': 1975,
#   u'loanGUID': u'121371790',
#   u'loanGrade': u'B5',
#   u'loanLength': 36,
#   u'loanRate': u'11.99',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 1975,
#   'loan_id': 121371790,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'credit_card',
#   u'searchrank': -1,
#   u'title': u'Credit card refinancing',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'705-709',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 8400,
#   u'loanAmt': 8400,
#   u'loanAmtRemaining': 2000,
#   u'loanGUID': u'121704925',
#   u'loanGrade': u'B3',
#   u'loanLength': 36,
#   u'loanRate': u'10.42',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2564521070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 2000,
#   'loan_id': 121704925,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'home_improvement',
#   u'searchrank': -1,
#   u'title': u'Home improvement',
#   u'wholeLoanTimeRemaining': -27478930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'710-714',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 3600,
#   u'loanAmt': 3600,
#   u'loanAmtRemaining': 2125,
#   u'loanGUID': u'121397209',
#   u'loanGrade': u'D2',
#   u'loanLength': 36,
#   u'loanRate': u'18.06',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 2125,
#   'loan_id': 121397209,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'other',
#   u'searchrank': -1,
#   u'title': u'Other',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'675-679',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 5000,
#   u'loanAmt': 5000,
#   u'loanAmtRemaining': 2225,
#   u'loanGUID': u'121724239',
#   u'loanGrade': u'B2',
#   u'loanLength': 36,
#   u'loanRate': u'9.93',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 2225,
#   'loan_id': 121724239,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'credit_card',
#   u'searchrank': -1,
#   u'title': u'Credit card refinancing',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'695-699',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 5350,
#   u'loanAmt': 5350,
#   u'loanAmtRemaining': 2275,
#   u'loanGUID': u'121366442',
#   u'loanGrade': u'E2',
#   u'loanLength': 36,
#   u'loanRate': u'23.88',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 2275,
#   'loan_id': 121366442,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'home_improvement',
#   u'searchrank': -1,
#   u'title': u'Home improvement',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'660-664',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 10000,
#   u'loanAmt': 10000,
#   u'loanAmtRemaining': 2400,
#   u'loanGUID': u'121402243',
#   u'loanGrade': u'B4',
#   u'loanLength': 36,
#   u'loanRate': u'10.91',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2506921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 2400,
#   'loan_id': 121402243,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'credit_card',
#   u'searchrank': -1,
#   u'title': u'Credit card refinancing',
#   u'wholeLoanTimeRemaining': -85078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'670-674',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 7000,
#   u'loanAmt': 7000,
#   u'loanAmtRemaining': 2750,
#   u'loanGUID': u'121429695',
#   u'loanGrade': u'D4',
#   u'loanLength': 36,
#   u'loanRate': u'20.00',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2550121070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 2750,
#   'loan_id': 121429695,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'other',
#   u'searchrank': -1,
#   u'title': u'Other',
#   u'wholeLoanTimeRemaining': -41878930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'685-689',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 11375,
#   u'loanAmt': 11375,
#   u'loanAmtRemaining': 2775,
#   u'loanGUID': u'121423361',
#   u'loanGrade': u'B4',
#   u'loanLength': 36,
#   u'loanRate': u'10.91',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2564521070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 2775,
#   'loan_id': 121423361,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'credit_card',
#   u'searchrank': -1,
#   u'title': u'Credit card refinancing',
#   u'wholeLoanTimeRemaining': -27478930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'665-669',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 4325,
#   u'loanAmt': 4325,
#   u'loanAmtRemaining': 2925,
#   u'loanGUID': u'120276113',
#   u'loanGrade': u'D2',
#   u'loanLength': 36,
#   u'loanRate': u'18.06',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 2925,
#   'loan_id': 120276113,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -1,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'680-684',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 5000,
#   u'loanAmt': 5000,
#   u'loanAmtRemaining': 3075,
#   u'loanGUID': u'121349055',
#   u'loanGrade': u'D3',
#   u'loanLength': 36,
#   u'loanRate': u'19.03',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 3075,
#   'loan_id': 121349055,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -1,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'700-704',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 19200,
#   u'loanAmt': 19200,
#   u'loanAmtRemaining': 3175,
#   u'loanGUID': u'121402407',
#   u'loanGrade': u'B3',
#   u'loanLength': 36,
#   u'loanRate': u'10.42',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 3175,
#   'loan_id': 121402407,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -1,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'675-679',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 18000,
#   u'loanAmt': 18000,
#   u'loanAmtRemaining': 3200,
#   u'loanGUID': u'120204805',
#   u'loanGrade': u'B2',
#   u'loanLength': 36,
#   u'loanRate': u'9.93',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2564521070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 3200,
#   'loan_id': 120204805,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -1,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -27478930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'675-679',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 8000,
#   u'loanAmt': 8000,
#   u'loanAmtRemaining': 3500,
#   u'loanGUID': u'121412200',
#   u'loanGrade': u'D5',
#   u'loanLength': 36,
#   u'loanRate': u'21.45',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2506921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 3500,
#   'loan_id': 121412200,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -1,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -85078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'680-684',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 9800,
#   u'loanAmt': 9800,
#   u'loanAmtRemaining': 3525,
#   u'loanGUID': u'121719169',
#   u'loanGrade': u'C3',
#   u'loanLength': 36,
#   u'loanRate': u'14.08',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 3525,
#   'loan_id': 121719169,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -1,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'705-709',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 13000,
#   u'loanAmt': 13000,
#   u'loanAmtRemaining': 3700,
#   u'loanGUID': u'121407490',
#   u'loanGrade': u'B5',
#   u'loanLength': 36,
#   u'loanRate': u'11.99',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 3700,
#   'loan_id': 121407490,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'credit_card',
#   u'searchrank': -1,
#   u'title': u'Credit card refinancing',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'680-684',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 10000,
#   u'loanAmt': 10000,
#   u'loanAmtRemaining': 3750,
#   u'loanGUID': u'121379450',
#   u'loanGrade': u'D3',
#   u'loanLength': 36,
#   u'loanRate': u'19.03',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2406121070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 3750,
#   'loan_id': 121379450,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -1,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -185878930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'690-694',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 18000,
#   u'loanAmt': 18000,
#   u'loanAmtRemaining': 3775,
#   u'loanGUID': u'120639665',
#   u'loanGrade': u'D3',
#   u'loanLength': 36,
#   u'loanRate': u'19.03',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 3775,
#   'loan_id': 120639665,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'credit_card',
#   u'searchrank': -1,
#   u'title': u'Credit card refinancing',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'660-664',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 9000,
#   u'loanAmt': 9000,
#   u'loanAmtRemaining': 3825,
#   u'loanGUID': u'121715701',
#   u'loanGrade': u'D3',
#   u'loanLength': 36,
#   u'loanRate': u'19.03',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 3825,
#   'loan_id': 121715701,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -1,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'735-739',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 15000,
#   u'loanAmt': 15000,
#   u'loanAmtRemaining': 4075,
#   u'loanGUID': u'121217040',
#   u'loanGrade': u'D3',
#   u'loanLength': 36,
#   u'loanRate': u'19.03',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2492521070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 4075,
#   'loan_id': 121217040,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -1,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -99478930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'675-679',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 7500,
#   u'loanAmt': 7500,
#   u'loanAmtRemaining': 4275,
#   u'loanGUID': u'121425319',
#   u'loanGrade': u'D1',
#   u'loanLength': 36,
#   u'loanRate': u'17.09',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2506921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 4275,
#   'loan_id': 121425319,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'other',
#   u'searchrank': -1,
#   u'title': u'Other',
#   u'wholeLoanTimeRemaining': -85078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'665-669',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 10000,
#   u'loanAmt': 10000,
#   u'loanAmtRemaining': 4325,
#   u'loanGUID': u'121112111',
#   u'loanGrade': u'C1',
#   u'loanLength': 36,
#   u'loanRate': u'12.62',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 4325,
#   'loan_id': 121112111,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -1,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'680-684',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 9700,
#   u'loanAmt': 9700,
#   u'loanAmtRemaining': 4500,
#   u'loanGUID': u'121704578',
#   u'loanGrade': u'D2',
#   u'loanLength': 36,
#   u'loanRate': u'18.06',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 4500,
#   'loan_id': 121704578,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'credit_card',
#   u'searchrank': -1,
#   u'title': u'Credit card refinancing',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'730-734',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 9600,
#   u'loanAmt': 9600,
#   u'loanAmtRemaining': 4575,
#   u'loanGUID': u'120048669',
#   u'loanGrade': u'B1',
#   u'loanLength': 36,
#   u'loanRate': u'9.44',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 4575,
#   'loan_id': 120048669,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -1,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'730-734',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 10000,
#   u'loanAmt': 10000,
#   u'loanAmtRemaining': 4625,
#   u'loanGUID': u'121719166',
#   u'loanGrade': u'C1',
#   u'loanLength': 36,
#   u'loanRate': u'12.62',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 4625,
#   'loan_id': 121719166,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -1,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'660-664',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 13000,
#   u'loanAmt': 13000,
#   u'loanAmtRemaining': 4675,
#   u'loanGUID': u'121408841',
#   u'loanGrade': u'E2',
#   u'loanLength': 36,
#   u'loanRate': u'23.88',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2506921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 4675,
#   'loan_id': 121408841,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -1,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -85078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'660-664',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 6600,
#   u'loanAmt': 6600,
#   u'loanAmtRemaining': 5200,
#   u'loanGUID': u'121401662',
#   u'loanGrade': u'D2',
#   u'loanLength': 36,
#   u'loanRate': u'18.06',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 5200,
#   'loan_id': 121401662,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -1,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'680-684',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 8575,
#   u'loanAmt': 8575,
#   u'loanAmtRemaining': 5850,
#   u'loanGUID': u'121705758',
#   u'loanGrade': u'D2',
#   u'loanLength': 36,
#   u'loanRate': u'18.06',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2564521070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 5850,
#   'loan_id': 121705758,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
# ...
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 28000,
#   u'loanAmt': 28000,
#   u'loanAmtRemaining': 15700,
#   u'loanGUID': u'121374997',
#   u'loanGrade': u'C1',
#   u'loanLength': 36,
#   u'loanRate': u'12.62',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 15700,
#   'loan_id': 121374997,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -1,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'735-739',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 20000,
#   u'loanAmt': 20000,
#   u'loanAmtRemaining': 15850,
#   u'loanGUID': u'120946408',
#   u'loanGrade': u'C2',
#   u'loanLength': 36,
#   u'loanRate': u'13.59',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 15850,
#   'loan_id': 120946408,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'home_improvement',
#   u'searchrank': -1,
#   u'title': u'Home improvement',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'670-674',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 20000,
#   u'loanAmt': 20000,
#   u'loanAmtRemaining': 16200,
#   u'loanGUID': u'121723240',
#   u'loanGrade': u'D1',
#   u'loanLength': 36,
#   u'loanRate': u'17.09',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 16200,
#   'loan_id': 121723240,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -1,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'685-689',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 20775,
#   u'loanAmt': 20775,
#   u'loanAmtRemaining': 16950,
#   u'loanGUID': u'121408059',
#   u'loanGrade': u'D4',
#   u'loanLength': 36,
#   u'loanRate': u'20.00',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2492521070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 16950,
#   'loan_id': 121408059,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -1,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -99478930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'690-694',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 25000,
#   u'loanAmt': 25000,
#   u'loanAmtRemaining': 17375,
#   u'loanGUID': u'121330685',
#   u'loanGrade': u'B2',
#   u'loanLength': 36,
#   u'loanRate': u'9.93',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2564521070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 17375,
#   'loan_id': 121330685,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -1,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -27478930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'685-689',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 25000,
#   u'loanAmt': 25000,
#   u'loanAmtRemaining': 18425,
#   u'loanGUID': u'121331953',
#   u'loanGrade': u'D1',
#   u'loanLength': 36,
#   u'loanRate': u'17.09',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 18425,
#   'loan_id': 121331953,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -1,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'675-679',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 32400,
#   u'loanAmt': 32400,
#   u'loanAmtRemaining': 19775,
#   u'loanGUID': u'121283792',
#   u'loanGrade': u'D3',
#   u'loanLength': 36,
#   u'loanRate': u'19.03',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2506921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 19775,
#   'loan_id': 121283792,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -1,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -85078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'665-669',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 35000,
#   u'loanAmt': 35000,
#   u'loanAmtRemaining': 20850,
#   u'loanGUID': u'121372671',
#   u'loanGrade': u'E4',
#   u'loanLength': 36,
#   u'loanRate': u'25.82',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2420521070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 20850,
#   'loan_id': 121372671,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'credit_card',
#   u'searchrank': -1,
#   u'title': u'Credit card refinancing',
#   u'wholeLoanTimeRemaining': -171478930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'695-699',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 27000,
#   u'loanAmt': 27000,
#   u'loanAmtRemaining': 21700,
#   u'loanGUID': u'121429873',
#   u'loanGrade': u'B2',
#   u'loanLength': 36,
#   u'loanRate': u'9.93',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2564521070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 21700,
#   'loan_id': 121429873,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -1,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -27478930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'725-729',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 30000,
#   u'loanAmt': 30000,
#   u'loanAmtRemaining': 21725,
#   u'loanGUID': u'121399349',
#   u'loanGrade': u'B3',
#   u'loanLength': 36,
#   u'loanRate': u'10.42',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2506921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 21725,
#   'loan_id': 121399349,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'credit_card',
#   u'searchrank': -1,
#   u'title': u'Credit card refinancing',
#   u'wholeLoanTimeRemaining': -85078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'730-734',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 27500,
#   u'loanAmt': 27500,
#   u'loanAmtRemaining': 22250,
#   u'loanGUID': u'121287141',
#   u'loanGrade': u'E4',
#   u'loanLength': 36,
#   u'loanRate': u'25.82',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 22250,
#   'loan_id': 121287141,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -1,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'695-699',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 30000,
#   u'loanAmt': 30000,
#   u'loanAmtRemaining': 22700,
#   u'loanGUID': u'121274939',
#   u'loanGrade': u'E2',
#   u'loanLength': 36,
#   u'loanRate': u'23.88',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2506921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 22700,
#   'loan_id': 121274939,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -1,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -85078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'685-689',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 30000,
#   u'loanAmt': 30000,
#   u'loanAmtRemaining': 23750,
#   u'loanGUID': u'120232649',
#   u'loanGrade': u'B4',
#   u'loanLength': 36,
#   u'loanRate': u'10.91',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2506921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 23750,
#   'loan_id': 120232649,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -1,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -85078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'715-719',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 33375,
#   u'loanAmt': 33375,
#   u'loanAmtRemaining': 24125,
#   u'loanGUID': u'121401740',
#   u'loanGrade': u'E5',
#   u'loanLength': 36,
#   u'loanRate': u'26.30',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2478121070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 24125,
#   'loan_id': 121401740,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -1,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -113878930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'675-679',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 35000,
#   u'loanAmt': 35000,
#   u'loanAmtRemaining': 25375,
#   u'loanGUID': u'121352343',
#   u'loanGrade': u'G3',
#   u'loanLength': 36,
#   u'loanRate': u'30.89',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2564521070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 25375,
#   'loan_id': 121352343,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -1,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -27478930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'665-669',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 35000,
#   u'loanAmt': 35000,
#   u'loanAmtRemaining': 29400,
#   u'loanGUID': u'120110501',
#   u'loanGrade': u'E3',
#   u'loanLength': 36,
#   u'loanRate': u'24.85',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2492521070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 29400,
#   'loan_id': 120110501,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'home_improvement',
#   u'searchrank': -1,
#   u'title': u'Home improvement',
#   u'wholeLoanTimeRemaining': -99478930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'685-689',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 35000,
#   u'loanAmt': 35000,
#   u'loanAmtRemaining': 29800,
#   u'loanGUID': u'121402929',
#   u'loanGrade': u'D1',
#   u'loanLength': 36,
#   u'loanRate': u'17.09',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2492521070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 29800,
#   'loan_id': 121402929,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -1,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -99478930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'680-684',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 34550,
#   u'loanAmt': 34550,
#   u'loanAmtRemaining': 30600,
#   u'loanGUID': u'121347020',
#   u'loanGrade': u'E1',
#   u'loanLength': 36,
#   u'loanRate': u'22.91',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2492521070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 30600,
#   'loan_id': 121347020,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'major_purchase',
#   u'searchrank': -1,
#   u'title': u'Major purchase',
#   u'wholeLoanTimeRemaining': -99478930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'700-704',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 35000,
#   u'loanAmt': 35000,
#   u'loanAmtRemaining': 32450,
#   u'loanGUID': u'121430902',
#   u'loanGrade': u'E5',
#   u'loanLength': 36,
#   u'loanRate': u'26.30',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2578921070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 32450,
#   'loan_id': 121430902,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'small_business',
#   u'searchrank': -1,
#   u'title': u'Business',
#   u'wholeLoanTimeRemaining': -13078930},
#  {u'alreadyInvestedIn': False,
#   u'alreadySelected': False,
#   u'amountToInvest': 0,
#   u'fico': u'675-679',
#   u'hasCosigner': False,
#   u'isInCurrentOrder': False,
#   u'isWholeLoan': 0,
#   u'loanAmountRequested': 40000,
#   u'loanAmt': 40000,
#   u'loanAmtRemaining': 32975,
#   u'loanGUID': u'121111692',
#   u'loanGrade': u'B2',
#   u'loanLength': 36,
#   u'loanRate': u'9.93',
#   u'loanRateDiff': u'.00',
#   u'loanTimeRemaining': 2492521070L,
#   u'loanType': u'Personal',
#   u'loanUnfundedAmount': 32975,
#   'loan_id': 121111692,
#   u'loan_status': u'INFUNDING',
#   u'noFee': 0,
#   u'primeFractions': 0,
#   u'primeMarkedInvestment': 0,
#   u'primeTotalInvestment': 0,
#   u'primeUnfundedAmount': 0,
#   u'purpose': u'debt_consolidation',
#   u'searchrank': -1,
#   u'title': u'Debt consolidation',
#   u'wholeLoanTimeRemaining': -99478930}]

# %%
# Filter By Loan ID

filter = FilterByLoanID([119428432, 120117441])
results = lc.search(filter)
pprint(results)
# Out:
# {u'loans': [{u'alreadyInvestedIn': False,
#              u'alreadySelected': False,
#              u'amountToInvest': 0,
#              u'fico': u'680-684',
#              u'hasCosigner': False,
#              u'isInCurrentOrder': False,
#              u'isWholeLoan': 0,
#              u'loanAmountRequested': 10075,
#              u'loanAmt': 10075,
#              u'loanAmtRemaining': 350,
#              u'loanGUID': u'119428432',
#              u'loanGrade': u'E2',
#              u'loanLength': 36,
#              u'loanRate': u'23.88',
#              u'loanRateDiff': u'.00',
#              u'loanTimeRemaining': 2320963723L,
#              u'loanType': u'Personal',
#              u'loanUnfundedAmount': 350,
#              'loan_id': 119428432,
#              u'loan_status': u'INFUNDING',
#              u'noFee': 0,
#              u'primeFractions': 0,
#              u'primeMarkedInvestment': 0,
#              u'primeTotalInvestment': 0,
#              u'primeUnfundedAmount': 0,
#              u'purpose': u'debt_consolidation',
#              u'searchrank': -4.7478206e-06,
#              u'title': u'Debt consolidation',
#              u'wholeLoanTimeRemaining': -26882277}],
#  u'totalRecords': 1}

# %% [markdown]
# ## 2. Lending Club's API
#
# Lending Club offers REST API services that allow investors to access the Lending Club platform programmatically. The API was created to help investors who want to customize and independently automate their investments in Lending Club loans.
#
# Lending Club offers several services via the API that allow users to:
#
#
#
# ### Account resource
#
#   1.Summary: provides a summary of the investor's account.
#
# *https://api.lendingclub.com/api/investor/version/accounts/investor_id/summary*
#
#   2.Available cash: provides the most up to date value of the cash available in the investor's account.
#
# *https://api.lendingclub.com/api/investor/version/accounts/investor_id/availablecash*
#
#   3.Transfer Funds: enables user to add funds to the investor's account.
#
# *https://api.lendingclub.com/api/investor/version/accounts/investor_id/funds/add*
#
#   4.Pending Transfers: enables user to find pending fund transfers for the investor's account.
#
# *https://api.lendingclub.com/api/investor/version/accounts/investor_id/funds/pending*
#
#   5.Cancel Transfers: enables user to cancel the funds transfer initiated.
#
# *https://api.lendingclub.com/api/investor/version/accounts/investor_id/funds/cancel*
#
#   6.Notes owned: provides a list of notes that are owned by the investor.
#
# *https://api.lendingclub.com/api/investor/version/accounts/investor_id/notes*
#
#   7.Detailed notes owned: provides a detailed list of notes that are owned by the investor. In addition to the data provided by Owned Notes resource, this one adds financial information regarding the notes.
#
# *https://api.lendingclub.com/api/investor/version/accounts/investor_id/detailednotes*
#
#   8.Portfolio owned:  provides a list of all portfolios that are owned by the investor.
#
# *https://api.lendingclub.com/api/investor/version/accounts/investor_id/portfolios*
#
#   9.Create portfolio: allows investors to create a new portfolio.
#
# *https://api.lendingclub.com/api/investor/version/accounts/investor_id/portfolios*
#
#   10.Submit order: allows investors to submit a new order for one or more loans.
#
# *https://api.lendingclub.com/api/investor/version/accounts/investor_id/orders*
#
#   11.Filters: allows investors to retrieve a list of the filters that they have created.
#
# *https://api.lendingclub.com/api/investor/version/accounts/investor_id/filters*
#
# ### Loan resource
#
#   1.Listed loans: provides the details of the loans currently listed on the Lending Club platform. The list contains the same loans that an investor would see on the browse loans page on the Lending Club website. The same restrictions that Lending Club applies on the browse loans page also apply to the browse loans API. The API currently returns either the entire list of loans listed on the platform or only the loans listed in the recent listing period. Loans are listed on the Lending Club platform at 6AM, 10AM, 2PM, and 6PM every day.
#
# **https://api.lendingclub.com/api/investor/v1/loans/listing**
#
#
#
# ### Versioning
#
# The current active version of LC Rest web services is v1

# %%
import pandas as pd
import requests

# %% [markdown]
# | HTTP Accept Header | Content Type Resolution |
# |--------------------|-------------------------|
# | application/json   | JSON                    |
# | application/xml    | XML                     |
# | text/plain         | CSV                     |
# | No Accept Header   | JSON (Default)          |

# %%
url = 'https://api.lendingclub.com/api/investor/v1/loans/listing'
headers = {'Authorization': 'hZQIWsD76GIvY4rC773+kM9zfvY=', 
           'Accept':'application/json'}
r = requests.get(url, headers = headers)
raw = r.json()
len(raw['loans'])
# Out:
# 87
